# %%
import numpy as np 
import matplotlib.pyplot as plt

data = np.loadtxt('nodalForces.txt')
dofNum = 7
disp = data[:,dofNum]
dt = 0.01
T = 5
time = np.arange(0,T,dt)
print(time.size)
print(disp.size)

'''title = 'Average acceleration'
f = plt.figure()
f.set_figwidth(20)
f.set_figheight(3)
plt.plot(time, disp, label='dof number '+str(dofNum))
plt.xlabel('Time [t]')
plt.ylabel('Nodal Force [K*d]')
plt.grid()
plt.legend()
plt.title(title)
plt.show()'''

title = 'Time History for 4DOF System Subjected to Static Load - Average Acceleration, dt = '+str(dt)
f = plt.figure()
f.set_figwidth(20)
f.set_figheight(3)
plt.plot(time, disp, color='darkslategrey', label='Displacement for mid truss node in z-direction')
plt.xlabel('Time [t]')
plt.ylabel('Displacement [K/F]')
plt.grid()
plt.legend()
plt.title(title)
plt.show()

dofNum = 2
disp = data[:,dofNum]
dt = 0.01
T = 5
time = np.arange(0,T,dt)
title = 'Average acceleration'
f = plt.figure()
f.set_figwidth(20)
f.set_figheight(3)
plt.plot(time, disp, color='darkslategrey',label='Moment left support of arch')
plt.xlabel('Time [t]')
plt.ylabel('Nodal Moment [K*d]')
plt.grid()
plt.legend()
plt.title(title)
plt.show()
# Out:
# 500
# 500

# %%
x = np.array(
    [
    [1,5,1,1],
    [2,2,2,2],
    [3,5,3,3],
    [4,4,4,4]
    ]
)
print(x[::2,1])
# Out:
# [5 5]
